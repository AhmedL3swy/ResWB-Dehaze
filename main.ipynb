# %% [markdown]
# #Clone (Private Repo)

# %% [markdown]
# Token : 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

# %%
import os

# %%
os.chdir("/content/")
# !git clone "https://Ahmed-Alesawy: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@github.com/Ahmed-Alesawy/ResWB-Dehaze.git"
# Out:
# Cloning into 'ResWB-Dehaze'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 38 (delta 5), reused 32 (delta 5), pack-reused 0
# Unpacking objects: 100% (38/38), 31.06 KiB | 2.39 MiB/s, done.

# %% [markdown]
# #Train

# %%
os.chdir('/content/ResWB-Dehaze')
# !pip install -f requirements.txt
# Out:
# MyEnsembleNet parameters: 31417322
# --- weight loaded ---
# We are in epoch: 1
# /content/ResWB-Dehaze/utils.py:16: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_list = [ssim1(dehaze_list_np[ind],  gt_list_np[ind], data_range=1, multichannel=True) for ind in range(len(dehaze_list))]
# AVG PSNR:  24.097573272973168 AVG SSIM:  0.7628044737709894 AVG Loss:  0.1253494479176071
# We are in epoch: 2
# Traceback (most recent call last):
#   File "/content/ResWB-Dehaze/train.py", line 108, in <module>
#     for batch_idx, (hazy, clean, clean_sobel) in enumerate(train_loader):
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py", line 628, in __next__
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py", line 671, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
# ...

# %%
os.chdir('/content/ResWB-Dehaze')
# !python train.py

# %% [markdown]
# #Test

# %%
os.chdir('/content/ResWB-Dehaze')
# !python test.py
# Out:
# MyEnsembleNet parameters: 31417322
# --- weight loaded ---
# -----Testing-----
# /content/ResWB-Dehaze/utils.py:16: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_list = [ssim1(dehaze_list_np[ind],  gt_list_np[ind], data_range=1, multichannel=True) for ind in range(len(dehaze_list))]
# PSNR:  19.751649166506105 SSIM:  0.6935394167900085
